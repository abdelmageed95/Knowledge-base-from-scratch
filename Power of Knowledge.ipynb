# %%
# references : 
 
#  Coreference Resolution 
#   NeuralCoref Library for coreferece resolution  https://awesomeopensource.com/projects/neuralcore
    # https://medium.com/huggingface/state-of-the-art-neural-coreference-resolution-for-chatbots-3302365dcf30
    # https://github.com/huggingface/neuralcoref
    # https://stanfordnlp.github.io/CoreNLP/coref.html
    # https://awesomeopensource.com/projects/neuralcoref



# Entity Linking 
# https://medium.com/analytics-vidhya/entity-linking-a-primary-nlp-task-for-information-extraction-22f9d4b90aa8
# https://sobigdata.d4science.org/web/tagme/tagme-help
# http://wikifier.org/info.html#wikification 
#http://wikifier.org/info.html 


# Relation Extraction 
#  OpenNRE Library for relation extraction 

    #  """"   Han, X., Gao, T., Yao, Y., Ye, D., Liu, Z. and Sun, M., 2019. 
    #         OpenNRE: An open and extensible toolkit for neural relation extraction.
    #         arXiv preprint arXiv:1909.13078.  """
        
    # @inproceedings{han-etal-2019-opennre,
    # title = "{O}pen{NRE}: An Open and Extensible Toolkit for Neural Relation Extraction",
    # author = "Han, Xu and Gao, Tianyu and Yao, Yuan and Ye, Deming and Liu, Zhiyuan and Sun, Maosong",
    # booktitle = "Proceedings of EMNLP-IJCNLP: System Demonstrations",
    # year = "2019",
    # url = "https://www.aclweb.org/anthology/D19-3029",
    # doi = "10.18653/v1/D19-3029",
    # pages = "169--174"


#

# %% [markdown]
# ![Picture1.png](data:image/png;base64,...)

# %% [markdown]
# ## **Install The Requirments**

# %%
# !git clone https://github.com/thunlp/OpenNRE.git
# Out:
# Cloning into 'OpenNRE'...
# remote: Enumerating objects: 1514, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 1514 (delta 81), reused 82 (delta 42), pack-reused 1377
# Receiving objects: 100% (1514/1514), 266.83 MiB | 27.72 MiB/s, done.
# Resolving deltas: 100% (901/901), done.

# %%
# !pip install -U spacy==2.1.0
# !python -m spacy download en
# !pip uninstall -y neuralcoref 
# !pip install neuralcoref --no-binary neuralcoref
# !pip install wikipedia
# Out:
# ...
#      |████████████████████████████████| 27.7 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 2.1 MB 35.3 MB/s
# ...
#      |████████████████████████████████| 82 kB 421 kB/s
# ...
#      |████████████████████████████████| 3.2 MB 31.8 MB/s
# ...
#   Attempting uninstall: preshed
#     Found existing installation: preshed 3.0.6
#     Uninstalling preshed-3.0.6:
#       Successfully uninstalled preshed-3.0.6
#   Attempting uninstall: plac
#     Found existing installation: plac 1.1.3
#     Uninstalling plac-1.1.3:
#       Successfully uninstalled plac-1.1.3
#   Attempting uninstall: blis
#     Found existing installation: blis 0.4.1
#     Uninstalling blis-0.4.1:
#       Successfully uninstalled blis-0.4.1
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.3.3
#     Uninstalling jsonschema-4.3.3:
# ...

# %%
# !pip install torch==1.6.0
# !pip install transformers==3.4.0
# !pip install pytest==5.3.2
# !pip install scikit-learn==0.22.1
# !pip install scipy==1.4.1
# !pip install nltk>=3.6.4
# !python setup.py install
# !python setup.py develop
# Out:
# running install
# running bdist_egg
# running egg_info
# creating opennre.egg-info
# writing opennre.egg-info/PKG-INFO
# writing dependency_links to opennre.egg-info/dependency_links.txt
# writing top-level names to opennre.egg-info/top_level.txt
# writing manifest file 'opennre.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'opennre.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/opennre
# copying opennre/pretrain.py -> build/lib/opennre
# copying opennre/__init__.py -> build/lib/opennre
# creating build/lib/opennre/framework
# copying opennre/framework/utils.py -> build/lib/opennre/framework
# copying opennre/framework/bag_re.py -> build/lib/opennre/framework
# copying opennre/framework/data_loader.py -> build/lib/opennre/framework
# copying opennre/framework/multi_label_sentence_re.py -> build/lib/opennre/framework
# ...

# %% [markdown]
# ## ***Import text from wikipedia***

# %%
import wikipedia
wikipedia.set_lang("en")
# wikipedia.page("Zinedine Zidane").images
# wikipedia.page('Zinedine Zidane').url
# wikipedia.page('Zinedine Zidane').categories
# wikipedia.page('Zinedine Zidane').links
summary = wikipedia.summary("Nikola Tesla")
summary
# Out:
# "Nikola Tesla ( TESS-lə; Serbian Cyrillic: Никола Тесла, pronounced [nǐkola têsla]; 10 July [O.S. 28 June] 1856 – 7 January 1943) was a Serbian-American inventor, electrical engineer, mechanical engineer, and futurist best known for his contributions to the design of the modern alternating current (AC) electricity supply system.Born and raised in the Austrian Empire, Tesla studied engineering and physics in the 1870s without receiving a degree, gaining practical experience in the early 1880s working in telephony and at Continental Edison in the new electric power industry. In 1884 he emigrated to the United States, where he became a naturalized citizen. He worked for a short time at the Edison Machine Works in New York City before he struck out on his own. With the help of partners to finance and market his ideas, Tesla set up laboratories and companies in New York to develop a range of electrical and mechanical devices. His alternating current (AC) induction motor and related polyph
# ...

# %%
articles = ['Nikola Tesla','Ahmed Zewail' , 'Ali Moustafa Mosharafa','Isaac Newton', 'Albert Einstein','Thomas Ediison']
#articles = ["Robert Lewandowski" ,"Cristiano Ronaldo" ,"Lional Messi"]
text = [wikipedia.page(article).content for article in articles]

text
# Out:
# ['Nikola Tesla ( TESS-lə; Serbian Cyrillic: Никола Тесла, pronounced [nǐkola têsla]; 10 July [O.S. 28 June] 1856 – 7 January 1943) was a Serbian-American inventor, electrical engineer, mechanical engineer, and futurist best known for his contributions to the design of the modern alternating current (AC) electricity supply system.Born and raised in the Austrian Empire, Tesla studied engineering and physics in the 1870s without receiving a degree, gaining practical experience in the early 1880s working in telephony and at Continental Edison in the new electric power industry. In 1884 he emigrated to the United States, where he became a naturalized citizen. He worked for a short time at the Edison Machine Works in New York City before he struck out on his own. With the help of partners to finance and market his ideas, Tesla set up laboratories and companies in New York to develop a range of electrical and mechanical devices. His alternating current (AC) induction motor and related polyp
# ...

# %% [markdown]
# ## ***Spliting Text to Paragraphs***

# %%
paragraphs = [ i.split('\n\n') for i in text ]
len(paragraphs)
# Out:
# 6

# %%
paragraphs[0][5]
# Out:
# '\n=== Working at Budapest Telephone Exchange ===\nTesla moved to Budapest, Hungary, in 1881 to work under Tivadar Puskás at a telegraph company, the Budapest Telephone Exchange. Upon arrival, Tesla realized that the company, then under construction, was not functional, so he worked as a draftsman in the Central Telegraph Office instead. Within a few months, the Budapest Telephone Exchange became functional, and Tesla was allocated the chief electrician position. During his employment, Tesla made many improvements to the Central Station equipment and claimed to have perfected a telephone repeater or amplifier, which was never patented nor publicly described.'

# %% [markdown]
# ## ***Coreference Resolution***
#  we use **NeuralCoref 4.0:** Coreference Resolution in spaCy with Neural Networks

# %%
import spacy
import neuralcoref

nlp = spacy.load('en_core_web_sm')
neuralcoref.add_to_pipe(nlp)

def coref_resolution(text):
  doc = nlp(text)
  tok_list = list(token.text_with_ws for token in doc)
  for cluster in doc._.coref_clusters:
      cluster_main_words = set(cluster.main.text.split(' '))
      for coref in cluster:
            if coref != cluster.main: 
                if coref.text != cluster.main.text and bool(set(coref.text.split(' ')).intersection(cluster_main_words)) == False:
                    tok_list[coref.start] = cluster.main.text + \
                        doc[coref.end-1].whitespace_
                    for i in range(coref.start+1, coref.end):
                        tok_list[i] = ""

  return "".join(tok_list)
# Out:
# 100%|██████████| 40155833/40155833 [00:03<00:00, 12149822.40B/s]

# %%
import re
def preprocessing(text):
    cleaned = []
    processed_paragraphs = []
    paragraphs = [ i.split('\n\n') for i in text ]

    for item in paragraphs:
      for paragraph in item:
        processed_paragraph = coref_resolution(paragraph)
        processed_paragraphs.append(processed_paragraph)
          
    for string in  processed_paragraphs:
      s = re.sub('[!#&()/;=@[\]^_`{|}~]', "", string)
      s = s.replace("\n" ,"")
      i = s.split()
      if len(i) > 5:
        cleaned.append(s)
    return cleaned

# %%
cleaned_text = preprocessing(text)
cleaned_text
# Out:
# ["Nikola Tesla  TESS-lə Serbian Cyrillic: Никола Тесла, pronounced nǐkola têsla 10 July O.S. 28 June 1856 – 7 January 1943 was a Serbian-American inventor, electrical engineer, mechanical engineer, and futurist best known for his contributions to the design of the modern alternating current AC electricity supply system.Born and raised in the Austrian Empire, Tesla studied engineering and physics in the 1870s without receiving a degree, gaining practical experience in the early 1880s working in telephony and at Continental Edison in the new electric power industry. In 1884 he emigrated to the United States, where he became a naturalized citizen. he worked for a short time at the Edison Machine Works in New York City before he struck out on he own. With the help of partners to finance and market he ideas, Tesla set up laboratories and companies in New York to develop a range of electrical and mechanical devices. he alternating current AC induction motor and related polyphase AC patents
# ...

# %%
len(cleaned_text)
# Out:
# 231

# %%
sentences = [] 
for i in cleaned_text:
  j = i.split(',')
  for s in j :
    sentences.append(s)

# %%
len(sentences)
# Out:
# 3065

# %%
sentences
# Out:
# ['Nikola Tesla  TESS-lə Serbian Cyrillic: Никола Тесла',
#  ' pronounced nǐkola têsla 10 July O.S. 28 June 1856 – 7 January 1943 was a Serbian-American inventor',
#  ' electrical engineer',
#  ' mechanical engineer',
#  ' and futurist best known for his contributions to the design of the modern alternating current AC electricity supply system.Born and raised in the Austrian Empire',
#  ' Tesla studied engineering and physics in the 1870s without receiving a degree',
#  ' gaining practical experience in the early 1880s working in telephony and at Continental Edison in the new electric power industry. In 1884 he emigrated to the United States',
#  ' where he became a naturalized citizen. he worked for a short time at the Edison Machine Works in New York City before he struck out on he own. With the help of partners to finance and market he ideas',
# ...

# %% [markdown]
# ## Named Entity Linking using Wikifier API

# %%
# this code belongs to Tomaz Bratanic Author of Graph algorithms for Data Science at Manning publication.

import urllib
import json

ENTITY_TYPES = ["human", "person", "company", "enterprise", "business", "geographic region",
                "human settlement", "geographic entity", "territorial entity type", "organization"]

#http://wikifier.org/info.html#wikification   

def wikifier(text, lang="en", threshold=0.85):
    """Function that fetches entity linking results from wikifier.com API"""
    # Prepare the URL.
    data = urllib.parse.urlencode([
        ("text", text), ("lang", lang),
        ("userKey", "tgbdmkpmkluegqfbawcwjywieevmza"),
        ("pageRankSqThreshold", "%g" %
         threshold), ("applyPageRankSqThreshold", "true"),
        ("nTopDfValuesToIgnore", "100"), ("nWordsToIgnoreFromList", "100"),
        ("wikiDataClasses", "true"), ("wikiDataClassIds", "false"),
        ("support", "true"), ("ranges", "false"), ("minLinkFrequency", "2"),
        ("includeCosines", "false"), ("maxMentionEntropy", "3")
    ])
    url = "http://www.wikifier.org/annotate-article"
    # Call the Wikifier and read the response.
    req = urllib.request.Request(url, data=data.encode("utf8"), method="POST")
    with urllib.request.urlopen(req, timeout=60) as f:
        response = f.read()
        response = json.loads(response.decode("utf8"))
    # Output the annotations.
    results = list()
    for annotation in response["annotations"]:
        # Filter out desired entity classes
        if ('wikiDataClasses' in annotation) and (any([el['enLabel'] in ENTITY_TYPES for el in annotation['wikiDataClasses']])):

            # Specify entity label
            if any([el['enLabel'] in ["human", "person"] for el in annotation['wikiDataClasses']]):
                label = 'Person'
            elif any([el['enLabel'] in ["company", "enterprise", "business", "organization"] for el in annotation['wikiDataClasses']]):
                label = 'Organization'
            elif any([el['enLabel'] in ["geographic region", "human settlement", "geographic entity", "territorial entity type"] for el in annotation['wikiDataClasses']]):
                label = 'Location'
            else:
                label = None

            results.append({'title': annotation['title'], 'wikiId': annotation['wikiDataItemId'], 'label': label,
                            'characters': [(el['chFrom'], el['chTo']) for el in annotation['support']]})
    return results

# %%
wiki_list = wikifier(sentences[56])
wiki_list
# Out:
# [{'characters': [(59, 66)],
#   'label': 'Organization',
#   'title': 'Tomingaj',
#   'wikiId': 'Q12643690'},
#  {'characters': [(88, 99), (93, 99)],
#   'label': 'Person',
#   'title': 'Mark Twain',
#   'wikiId': 'Q7245'},
#  {'characters': [(224, 227)],
#   'label': 'Organization',
#   'title': 'Graz',
#   'wikiId': 'Q13298'},
#  {'characters': [(242, 258)],
#   'label': 'Location',
#   'title': 'Military Frontier',
#   'wikiId': 'Q221242'},
#  {'characters': [(293, 297)],
#   'label': 'Person',
#   'title': 'Nikola Tesla',
#   'wikiId': 'Q9036'}]

# %%
# label  = [ i['label']  for i in wiki_list ]
# entity = [ i['title']  for i in wiki_list ]
# wikiID = [ i['wikiId'] for i in wiki_list ]

# import pandas as pd 
# wiki_df = pd.DataFrame()
# wiki_df['label'] = label
# wiki_df['entity'] = entity
# wiki_df['wikiID'] = wikiID
# wiki_df

# %% [markdown]
# ## **Relationship extraction**

# %%
# %cd /content/OpenNRE
# Out:
# /content/OpenNRE

# %%
import opennre
relation_model = opennre.get_model('wiki80_bert_softmax')
# Out:
# 2022-03-12 20:32:14,959 - root - INFO - Loading BERT pre-trained checkpoint.

# %%
import itertools 
from tqdm import  tqdm
relations_list = []
for x in tqdm(sentences):
  # First get all the entities in the sentence
  entities = wikifier(x, threshold=0.8)
  # Iterate over every permutation pair of entities
  for permutation in itertools.permutations(entities, 2):
      for source in permutation[0]['characters']:
          for target in permutation[1]['characters']:
              # Relationship extraction with OpenNRE
              data = relation_model.infer(
                  {'text': x, 'h': {'pos': [source[0], source[1] + 1]}, 't': {'pos': [target[0], target[1] + 1]}})
              if data[1] > 0.8:
                  relations_list.append(
                      {'source': permutation[0]['title'], 'target': permutation[1]['title'], 'type': data[0]})
# Out:
# 100%|██████████| 3065/3065 [1:37:07<00:00,  1.90s/it]

# %%
len(relations_list)
# Out:
# 13

# %%
import pandas as pd
Triplet = pd.DataFrame(relations_list)
Triplet.rename(columns={ 'source' : 'Subject' , 'target': 'Object' , 'type' : 'Relation' }, inplace = True)
Triplet
# Out:
#             Subject              Object                  Relation
# 0            Serbia        Nikola Tesla  language of work or name
# 1      Nikola Tesla              Serbia  language of work or name
# 2      Nikola Tesla              Serbia    country of citizenship
# 3       Tesla, Inc.             Smiljan                 residence
# 4           Smiljan         Tesla, Inc.                 residence
# ...             ...                 ...                       ...
# 2748  Thomas Edison  Kalindi Commerford                  has part
# 2749     Henry Ford   Thomas Commerford                  has part
# 2750     Henry Ford  Kalindi Commerford                  has part
# 2751  Thomas Edison                 PBS          original network
# 2752            PBS       Thomas Edison          original network
#
# [2753 rows x 3 columns]

# %%
# remove duplicated triplets
from sklearn.utils import shuffle 
Triplet.drop_duplicates(keep = 'first' , inplace= True , ignore_index= True)
Triplet = Triplet[['Subject' , 'Relation' , 'Object']]
Triplet = shuffle(Triplet)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Triplet.to_csv(r'/content/drive/MyDrive/Triplet.csv')

# %%
# Triplet.to_json("json_triple1.json",orient = "split")
# Triplet.to_json("json_triple2.json",orient = "records")
# Triplet.to_json("json_triple3.json",orient = "index")
# Triplet.to_json("json_triple4.json",orient = "columns")
# Triplet.to_json("json_triple5.json",orient = "values")
# Triplet.to_json("json_triple6.json",orient = "table")

# %%
Triplet
# Out:
#                          Subject                Relation  \
# 1257          Ford Motor Company                owned by
# 955            Thurgood Marshall  country of citizenship
# 151                         Mars                 part of
# 250   St. Regis Hotels & Resorts                location
# 533                 Ahmed Zewail           work location
# ...                          ...                     ...
# 950             W. E. B. Du Bois             participant
# 921           Austen Chamberlain  country of citizenship
# 187                   Telefunken                has part
# 985               V. A. Sundaram                  spouse
# 41                         Paris                has part
#
#                                   Object
# 1257                          Henry Ford
# 955                        United States
# 151                                Radio
# 250                        New York City
# 533   California Institute of Technology
# ...
